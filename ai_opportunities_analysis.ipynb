# %% [markdown]
# <a href="https://colab.research.google.com/github/sehbaw/FL-/blob/main/ai_opportunities_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### What are some questions we are looking to answer?
#
# Q: What is the breakdown of the agencies that are
# <br>
# Q: What are the average
# <br>
# Q:
# <br>
# Q:
# <br>
# Q:
# <br>

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# OVerall Agency

# %%
data = pd.read_csv("https://raw.githubusercontent.com/kevinschaul/2025-Federal-Agency-AI-Use-Case-Inventory/refs/heads/main/data/clean/2025_consolidated_ai_inventory.csv")

# %%
data.head()

# %%
#drop nulls
data.dropna()

# %%
data

# %%
data.apply(pd.Series.value_counts)

# %%
#let us where the AI use cases are being maintained
grouped_counts = data['Bureau/Component'].value_counts()
print([grouped_counts)

# %%
agency = data[data["Use Case ID"].str.contains("DOE", na=False, regex=False)]
print(agency)

# %% [markdown]
# HHS

# %%
hhs_data = "https://github.com/kevinschaul/2025-Federal-Agency-AI-Use-Case-Inventory/blob/main/data/raw/department-of-health-and-human-services/hhs-ai-use-case-inventory-fy25.csv"
