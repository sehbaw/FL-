# %% [markdown]
# <a href="https://colab.research.google.com/github/sehbaw/FL-/blob/main/FL_simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip statements
# !pip install nvflare
# !pip install nibabel
# !pip install dicom
# !pip install

# %%
#import statements

# %%
#plot the visualization

# %%
#
